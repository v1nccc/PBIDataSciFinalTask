# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('loan_data_2007_2014.csv')
df.head()
# Out:
# /var/folders/t5/jyz_6zpx4v125p4fkssg7nkh0000gn/T/ipykernel_94922/1521905525.py:1: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('loan_data_2007_2014.csv')
#    Unnamed: 0       id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0           0  1077501    1296599       5000         5000           4975.0
# 1           1  1077430    1314167       2500         2500           2500.0
# 2           2  1077175    1313524       2400         2400           2400.0
# 3           3  1076863    1277178      10000        10000          10000.0
# 4           4  1075358    1311748       3000         3000           3000.0
#
#          term  int_rate  installment grade  ... total_bal_il il_util  \
# 0   36 months     10.65       162.87     B  ...          NaN     NaN
# 1   60 months     15.27        59.83     C  ...          NaN     NaN
# 2   36 months     15.96        84.33     C  ...          NaN     NaN
# ...

# %% [markdown]
# ### Data Understanding

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466285 entries, 0 to 466284
# Data columns (total 75 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Unnamed: 0                   466285 non-null  int64
#  1   id                           466285 non-null  int64
#  2   member_id                    466285 non-null  int64
#  3   loan_amnt                    466285 non-null  int64
#  4   funded_amnt                  466285 non-null  int64
#  5   funded_amnt_inv              466285 non-null  float64
#  6   term                         466285 non-null  object
#  7   int_rate                     466285 non-null  float64
#  8   installment                  466285 non-null  float64
#  9   grade                        466285 non-null  object
#  10  sub_grade                    466285 non-null  object
#  11  emp_title                    438697 non-null  object
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0            id     member_id      loan_amnt  \
# count  466285.000000  4.662850e+05  4.662850e+05  466285.000000
# mean   233142.000000  1.307973e+07  1.459766e+07   14317.277577
# std    134605.029472  1.089371e+07  1.168237e+07    8286.509164
# min         0.000000  5.473400e+04  7.047300e+04     500.000000
# 25%    116571.000000  3.639987e+06  4.379705e+06    8000.000000
# 50%    233142.000000  1.010790e+07  1.194108e+07   12000.000000
# 75%    349713.000000  2.073121e+07  2.300154e+07   20000.000000
# max    466284.000000  3.809811e+07  4.086083e+07   35000.000000
#
#          funded_amnt  funded_amnt_inv       int_rate    installment  \
# count  466285.000000    466285.000000  466285.000000  466285.000000
# mean    14291.801044     14222.329888      13.829236     432.061201
# std      8274.371300      8297.637788       4.357587     243.485550
# min       500.000000         0.000000       5.420000      15.670000
# ...

# %% [markdown]
# ### Dropping Columns that is not needes based on the data dictionary

# %%
columns_to_drop = ['url', 'desc', 'zip_code', 'emp_title', 'id', 'member_id', 'emp_length']

df.drop(columns=columns_to_drop, inplace=True)

# %% [markdown]
# ### Dropping Columns with Null or NaN values over 30%, to prevent bias when training the Machine Learning Model

# %%
missing_percentage = df.isna().sum() * 100 / len(df)
print("Percentage of Missing Values:\n", missing_percentage.sort_values(ascending=False))
# Out:
# Percentage of Missing Values:
#  inq_last_12m                 100.0
# total_bal_il                 100.0
# verification_status_joint    100.0
# dti_joint                    100.0
# annual_inc_joint             100.0
#                              ...
# total_pymnt_inv                0.0
# loan_amnt                      0.0
# total_rec_int                  0.0
# total_rec_late_fee             0.0
# total_rec_prncp                0.0
# Length: 68, dtype: float64

# %%
missing_percentage = df.isna().sum() * 100 / len(df)

columns_to_drop = missing_percentage[missing_percentage > 30].index

df = df.drop(columns=columns_to_drop)

# %%
missing_percentage = df.isnull().sum() * 100 / len(df)
print("Percentage of Missing Values:\n", missing_percentage.sort_values(ascending=False))
# Out:
# Percentage of Missing Values:
#  total_rev_hi_lim              15.071469
# tot_cur_bal                   15.071469
# tot_coll_amt                  15.071469
# last_pymnt_d                   0.080637
# revol_util                     0.072917
# collections_12_mths_ex_med     0.031097
# last_credit_pull_d             0.009007
# delinq_2yrs                    0.006219
# acc_now_delinq                 0.006219
# total_acc                      0.006219
# open_acc                       0.006219
# inq_last_6mths                 0.006219
# earliest_cr_line               0.006219
# pub_rec                        0.006219
# title                          0.004504
# annual_inc                     0.000858
# int_rate                       0.000000
# total_rec_late_fee             0.000000
# recoveries                     0.000000
# collection_recovery_fee        0.000000
# grade                          0.000000
# last_pymnt_amnt                0.000000
# installment                    0.000000
# ...

# %%
missing_percentage = df.isnull().sum() * 100 / len(df)

columns_to_drop = missing_percentage[missing_percentage > 30].index

df = df.drop(columns=columns_to_drop)

# %%
df.head()
# Out:
#    Unnamed: 0  loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 0           0       5000         5000           4975.0   36 months     10.65
# 1           1       2500         2500           2500.0   60 months     15.27
# 2           2       2400         2400           2400.0   36 months     15.96
# 3           3      10000        10000          10000.0   36 months     13.49
# 4           4       3000         3000           3000.0   60 months     12.69
#
#    installment grade sub_grade home_ownership  ...  last_pymnt_d  \
# 0       162.87     B        B2           RENT  ...        Jan-15
# 1        59.83     C        C4           RENT  ...        Apr-13
# 2        84.33     C        C5           RENT  ...        Jun-14
# 3       339.31     C        C1           RENT  ...        Jan-15
# 4        67.79     B        B5           RENT  ...        Jan-16
#
#   last_pymnt_amnt last_credit_pull_d collections_12_mths_ex_med policy_code  \
# ...

# %% [markdown]
# ### Dropping Columns based on Unique Values as it does not give any insights

# %%
unique_values = df.nunique()
print("Unique Values Count:\n", unique_values.sort_values(ascending= False))
# Out:
# Unique Values Count:
#  Unnamed: 0                    466285
# total_pymnt                   351609
# total_pymnt_inv               347659
# total_rec_int                 270249
# tot_cur_bal                   220690
# last_pymnt_amnt               198194
# total_rec_prncp               172713
# out_prncp_inv                 141189
# out_prncp                     135665
# title                          63098
# revol_bal                      58142
# installment                    55622
# annual_inc                     31901
# recoveries                     22773
# collection_recovery_fee        20275
# total_rev_hi_lim               14612
# funded_amnt_inv                 9854
# tot_coll_amt                    6321
# total_rec_late_fee              5808
# dti                             3997
# funded_amnt                     1354
# loan_amnt                       1352
# revol_util                      1269
# earliest_cr_line                 664
# int_rate                         506
# ...

# %%
single_value_columns = unique_values[unique_values == 1].index.tolist()
print("Columns with only one unique value:", single_value_columns)
# Out:
# Columns with only one unique value: ['policy_code', 'application_type']

# %%
columns_to_drop = ['policy_code', 'application_type']

df = df.drop(columns=columns_to_drop)

# %% [markdown]
# ### EDA

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style="whitegrid")
non_numeric_columns = df.select_dtypes(include=['object', 'category']).columns

for column in non_numeric_columns:
    plt.figure(figsize=(10, 6))  
    top_categories = df[column].value_counts().nlargest(10).index
    filtered_df = df[df[column].isin(top_categories)]

    sns.countplot(y=column, data=filtered_df, order=top_categories)
    
    plt.title(f'Frequency Distribution of {column} (Top 10 Categories)')
    plt.show()

# %%
for column in non_numeric_columns:
    top_categories_counts = df[column].value_counts().nlargest(10)
    top_categories = top_categories_counts.index

    filtered_df = df[df[column].isin(top_categories)]

    plt.figure(figsize=(8, 8))
    plt.pie(top_categories_counts, labels=top_categories, autopct='%1.1f%%', startangle=90)
    plt.title(f'Distribution of {column} (Top 10 Categories)')
    plt.show()

# %%
grade_mapping = {'A': 1, 'B': 2, 'C': 3, 'D': 4, 'E': 5, 'F': 6}
df['grade'] = df['grade'].map(grade_mapping)

numeric_cols = df.select_dtypes(include=['number']).columns
corr_matrix = df[numeric_cols].corr()
grade_corr = corr_matrix[['grade']].sort_values(by='grade', ascending=False)

plt.figure(figsize=(8, 12))

sns.heatmap(grade_corr, annot=True, fmt=".2f", cmap='coolwarm', cbar=True)

plt.title('Feature Correlation with Grade')
plt.show()

# %%
numerical_cols = df.select_dtypes(include=['number']).columns

sns.set(style="whitegrid")

for col in numerical_cols:
    plt.figure(figsize=(10, 6))  
    sns.boxplot(x=df[col])
    plt.title(f'Box plot of {col}')
    plt.xlabel(col)
    
    plt.show()
    plt.close()

# %% [markdown]
# ### Handling Missing Values

# %%
# Finding missing values
nan_values = df.isna().sum()
nan_values.sort_values(ascending=False)
# Out:
# total_rev_hi_lim              70276
# tot_cur_bal                   70276
# tot_coll_amt                  70276
# grade                          3322
# last_pymnt_d                    376
# revol_util                      340
# collections_12_mths_ex_med      145
# last_credit_pull_d               42
# delinq_2yrs                      29
# acc_now_delinq                   29
# total_acc                        29
# pub_rec                          29
# inq_last_6mths                   29
# earliest_cr_line                 29
# open_acc                         29
# title                            21
# annual_inc                        4
# purpose                           0
# total_pymnt_inv                   0
# funded_amnt                       0
# funded_amnt_inv                   0
# term                              0
# int_rate                          0
# installment                       0
# last_pymnt_amnt                   0
# sub_grade                         0
# ...

# %%
nan_values = df.isnull().sum()
nan_values.sort_values(ascending=False)
# Out:
# total_rev_hi_lim              70276
# tot_cur_bal                   70276
# tot_coll_amt                  70276
# grade                          3322
# last_pymnt_d                    376
# revol_util                      340
# collections_12_mths_ex_med      145
# last_credit_pull_d               42
# delinq_2yrs                      29
# acc_now_delinq                   29
# total_acc                        29
# pub_rec                          29
# inq_last_6mths                   29
# earliest_cr_line                 29
# open_acc                         29
# title                            21
# annual_inc                        4
# purpose                           0
# total_pymnt_inv                   0
# funded_amnt                       0
# funded_amnt_inv                   0
# term                              0
# int_rate                          0
# installment                       0
# last_pymnt_amnt                   0
# sub_grade                         0
# ...

# %%
numerical_cols = [
    'total_rev_hi_lim', 'tot_cur_bal', 'tot_coll_amt',
    'collections_12_mths_ex_med', 'delinq_2yrs', 'acc_now_delinq',
    'total_acc', 'pub_rec', 'inq_last_6mths', 'open_acc'
]

sns.set(style="whitegrid")

plt.figure(figsize=(15, 20))

for index, col in enumerate(numerical_cols):
    plt.subplot(len(numerical_cols), 1, index + 1)  
    sns.boxplot(x=df[col])
    plt.title(f'Box plot of {col}')
    plt.xlabel(col)

plt.tight_layout()  
plt.show()

# %%
columns_to_impute = [
    'total_rev_hi_lim', 'tot_cur_bal', 'tot_coll_amt',
    'collections_12_mths_ex_med', 'delinq_2yrs', 'acc_now_delinq',
    'total_acc', 'pub_rec', 'inq_last_6mths', 'open_acc','revol_util','annual_inc'
]

for column in columns_to_impute:
    median_value = df[column].median()
    df[column].fillna(median_value, inplace=True)

# %%
df = df.dropna(subset=['grade'])

# %%
nan_values = df.isna().sum()
nan_values.sort_values(ascending=False)
# Out:
# last_pymnt_d                  370
# last_credit_pull_d             42
# earliest_cr_line               29
# title                          21
# Unnamed: 0                      0
# total_rec_prncp                 0
# total_acc                       0
# initial_list_status             0
# out_prncp                       0
# out_prncp_inv                   0
# total_pymnt                     0
# total_pymnt_inv                 0
# total_rec_late_fee              0
# total_rec_int                   0
# revol_bal                       0
# recoveries                      0
# collection_recovery_fee         0
# last_pymnt_amnt                 0
# collections_12_mths_ex_med      0
# acc_now_delinq                  0
# tot_coll_amt                    0
# tot_cur_bal                     0
# revol_util                      0
# open_acc                        0
# pub_rec                         0
# annual_inc                      0
# funded_amnt                     0
# ...

# %%
nan_values = df.isnull().sum()
nan_values.sort_values(ascending=False)
# Out:
# last_pymnt_d                  370
# last_credit_pull_d             42
# earliest_cr_line               29
# title                          21
# Unnamed: 0                      0
# total_rec_prncp                 0
# total_acc                       0
# initial_list_status             0
# out_prncp                       0
# out_prncp_inv                   0
# total_pymnt                     0
# total_pymnt_inv                 0
# total_rec_late_fee              0
# total_rec_int                   0
# revol_bal                       0
# recoveries                      0
# collection_recovery_fee         0
# last_pymnt_amnt                 0
# collections_12_mths_ex_med      0
# acc_now_delinq                  0
# tot_coll_amt                    0
# tot_cur_bal                     0
# revol_util                      0
# open_acc                        0
# pub_rec                         0
# annual_inc                      0
# funded_amnt                     0
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 0           0       5000         5000           4975.0   36 months     10.65
# 1           1       2500         2500           2500.0   60 months     15.27
# 2           2       2400         2400           2400.0   36 months     15.96
# 3           3      10000        10000          10000.0   36 months     13.49
# 4           4       3000         3000           3000.0   60 months     12.69
#
#    installment  grade sub_grade home_ownership  ...  recoveries  \
# 0       162.87    2.0        B2           RENT  ...        0.00
# 1        59.83    3.0        C4           RENT  ...      117.08
# 2        84.33    3.0        C5           RENT  ...        0.00
# 3       339.31    3.0        C1           RENT  ...        0.00
# 4        67.79    2.0        B5           RENT  ...        0.00
#
#   collection_recovery_fee last_pymnt_d last_pymnt_amnt last_credit_pull_d  \
# ...

# %% [markdown]
# ### Encoding

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

for column in df.select_dtypes(include=['object']).columns:
    df[column] = le.fit_transform(df[column])

# %% [markdown]
# ### Model Training 1 (Logistic Regression)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
y = df['grade']

X = df.drop('grade', axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = model.predict(X_test)
evaluate = pd.DataFrame({'y_test': y_test, 'y_pred': y_pred})
evaluate
# Out:
#         y_test  y_pred
# 170654     3.0     3.0
# 318651     2.0     2.0
# 376959     3.0     3.0
# 393375     5.0     5.0
# 433603     2.0     2.0
# ...        ...     ...
# 360149     4.0     4.0
# 69636      2.0     2.0
# 201533     2.0     2.0
# 227332     1.0     1.0
# 73942      5.0     5.0
#
# [92593 rows x 2 columns]

# %%
# Logistic Regression
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report:")
print(classification_report(y_test, y_pred))

print("Accuracy Score:")
print(accuracy_score(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[15014   103     0     0     0     0]
#  [  150 27161     2     0     0     0]
#  [    1     2 25019     1     0     0]
#  [    0     0     1 15354     4     0]
#  [    0     0     0     6  7177     1]
#  [    0     0     0     0    25  2572]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.99      0.99     15117
#          2.0       1.00      0.99      1.00     27313
#          3.0       1.00      1.00      1.00     25023
#          4.0       1.00      1.00      1.00     15359
#          5.0       1.00      1.00      1.00      7184
#          6.0       1.00      0.99      0.99      2597
#
#     accuracy                           1.00     92593
#    macro avg       1.00      1.00      1.00     92593
# weighted avg       1.00      1.00      1.00     92593
#
# Accuracy Score:
# 0.9968032140658581

# %% [markdown]
# ### Model Training 2 (Random Forest Classifier)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(n_estimators=100, random_state=1)

classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=1)

# %%
y_pred = classifier.predict(X_test)

# %%
evaluate = pd.DataFrame({'y_test': y_test, 'y_pred': y_pred})
evaluate.head()
# Out:
#         y_test  y_pred
# 115455     2.0     2.0
# 309576     1.0     1.0
# 315753     4.0     4.0
# 403791     2.0     2.0
# 37361      4.0     4.0

# %%
# Random Forest Classifier
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report:")
print(classification_report(y_test, y_pred))

print("Accuracy Score:")
print(accuracy_score(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[18581     0     0     0     0     0]
#  [    0 34333     0     0     0     0]
#  [    0     0 31211     0     0     0]
#  [    0     0     0 19239     0     0]
#  [    0     0     0     2  9041     0]
#  [    0     0     0     0     8  3326]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       1.00      1.00      1.00     18581
#          2.0       1.00      1.00      1.00     34333
#          3.0       1.00      1.00      1.00     31211
#          4.0       1.00      1.00      1.00     19239
#          5.0       1.00      1.00      1.00      9043
#          6.0       1.00      1.00      1.00      3334
#
#     accuracy                           1.00    115741
#    macro avg       1.00      1.00      1.00    115741
# weighted avg       1.00      1.00      1.00    115741
#
# Accuracy Score:
# 0.9999136001935356
